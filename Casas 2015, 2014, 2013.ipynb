# %% [markdown]
# # Casas 2015

# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %config IPCompleter.greedy=True

df = pd.read_csv('/home/matias/Escritorio/notebook/properati-AR-2017-08-01-properties-sell.csv')

#Filtramos solo las propiedades de Capital Federal
propCF = df[df['state_name']== 'Capital Federal']

#Filtramos solo las Casas
casasCF = propCF[propCF['property_type']== 'house']

#En el año 2015
casasCF2015 = casasCF[casasCF.created_on.str.contains('2015')]

#Tomo los datos que me interesan de la tabla, en este caso solo me interesa el precio de las propiedades
casasCF2015S= casasCF2015[['place_name','place_with_parent_names','surface_total_in_m2', 'price_usd_per_m2']]

#Saco los Nan de la tabla resultante
casasCF2015S.dropna(inplace=True)

#Agrego el precio de la propiedad como columna como el producto de la superficie y el precio por m2
casasCF2015S['price_property'] = casasCF2015S['surface_total_in_m2']*casasCF2015S['price_usd_per_m2']

#Agrupo por Barrio
porBarrio = casasCF2015S.groupby('place_name').agg([np.mean, np.size])

#Elimino Capital Federal ya que es el resultado de los datos donde on estaba especificado el barrio
porBarrio2 = porBarrio.drop(['Capital Federal'])

#Filtramos barrios con poca representacion de datos > de 10 publicaciones
porBarrio3 = porBarrio2.loc[porBarrio2[('price_property','size')]>2,:]
                             
#Obtengo el Top de los barrios
topBarrios = porBarrio3.sort_values([('price_property','mean')], ascending =False)
topBarrios.head(57)
# Out:
# /home/matias/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/matias/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  surface_total_in_m2       price_usd_per_m2        \
#                                 mean  size             mean  size
# place_name
# Belgrano                  408.500000  10.0      2783.634352  10.0
# Villa Urquiza             187.333333   3.0      7941.798942   3.0
# Villa Crespo              216.833333   6.0      2322.012710   6.0
# Caballito                 300.000000   3.0      1838.396939   3.0
# Boedo                     392.666667   3.0      1131.410256   3.0
# Villa Pueyrredón          250.750000   4.0      1297.747529   4.0
# Barracas                  313.666667   3.0       762.677243   3.0
# Villa Lugano              240.400000   5.0       840.693676   5.0
# Retiro                    234.200000   5.0       847.855721   5.0
# Parque Patricios           71.800000   5.0      1490.620086   5.0
#
#                  price_property
#                            mean  size
# place_name
# Belgrano           1.078500e+06  10.0
# Villa Urquiza      6.046667e+05   3.0
# Villa Crespo       5.706667e+05   6.0
# Caballito          5.050000e+05   3.0
# Boedo              3.900000e+05   3.0
# Villa Pueyrredón   2.910000e+05   4.0
# Barracas           2.453333e+05   3.0
# Villa Lugano       2.000000e+05   5.0
# Retiro             1.442000e+05   5.0
# Parque Patricios   1.020000e+05   5.0

# %%
#Parte Grafica del Analisis de Propiedades

# %matplotlib inline
topBarrios_hist = topBarrios['price_property']

imagen =topBarrios_hist.plot(kind='bar',rot=90,figsize=(12,8))
imagen.set_xlabel('Barrios')

imagen.set_ylabel('Precio Propiedad Promedio')

imagen.set_title('Top 10 Precio Propiedad Promedio Por Barrio')

imagenEx = imagen.get_figure()
imagenEx.savefig('/home/matias/Escritorio/Datos/GraficoNote3.jpg')

# %% [markdown]
# # Casas 2014

# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %config IPCompleter.greedy=True

df = pd.read_csv('/home/matias/Escritorio/notebook/properati-AR-2017-08-01-properties-sell.csv')

#Filtramos solo las propiedades de Capital Federal
propCF = df[df['state_name']== 'Capital Federal']

#Filtramos solo las Casas
casasCF = propCF[propCF['property_type']== 'house']

#En el año 2014
casasCF2014 = casasCF[casasCF.created_on.str.contains('2014')]

#Tomo los datos que me interesan de la tabla, en este caso solo me interesa el precio de las propiedades
casasCF2014S= casasCF2014[['place_name','place_with_parent_names','surface_total_in_m2', 'price_usd_per_m2']]

#Saco los Nan de la tabla resultante
casasCF2014S.dropna(inplace=True)

#Agrego el precio de la propiedad como columna como el producto de la superficie y el precio por m2
casasCF2014S['price_property'] = casasCF2014S['surface_total_in_m2']*casasCF2014S['price_usd_per_m2']

#Agrupo por Barrio
porBarrio = casasCF2014S.groupby('place_name').agg([np.mean, np.size])

#Elimino Capital Federal ya que es el resultado de los datos donde on estaba especificado el barrio
porBarrio2 = porBarrio.drop(['Capital Federal'])

#Filtramos barrios con poca representacion de datos > de 10 publicaciones
porBarrio3 = porBarrio2.loc[porBarrio2[('price_property','size')]>1,:]
                             
#Obtengo el Top de los barrios
topBarrios = porBarrio3.sort_values([('price_property','mean')], ascending =False)
topBarrios.head(57)
# Out:
# /home/matias/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/matias/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  surface_total_in_m2      price_usd_per_m2       \
#                                 mean size             mean size
# place_name
# Belgrano                  330.833333  6.0      3465.985600  6.0
# Villa Ortuzar             450.000000  2.0      1550.000000  2.0
# Recoleta                  181.500000  2.0      2136.113896  2.0
# Flores                    369.571429  7.0      1237.224906  7.0
# Floresta                  159.500000  2.0      1969.136551  2.0
# Villa Pueyrredón          551.333333  3.0       778.576308  3.0
# Barracas                  256.000000  2.0       963.207620  2.0
# Monte Castro              231.000000  2.0      1190.804935  2.0
# Monserrat                 538.000000  2.0       635.526316  2.0
# Parque Patricios          215.000000  2.0       889.204545  2.0
# Mataderos                 227.750000  4.0       866.262375  4.0
# Villa Lugano              258.000000  3.0       614.606415  3.0
# Boca                      528.142857  7.0       458.724201  7.0
# Retiro                    225.000000  2.0       443.452381  2.0
#
#                  price_property
#                            mean size
# place_name
# Belgrano           1.011417e+06  6.0
# Villa Ortuzar      6.750000e+05  2.0
# Recoleta           6.287015e+05  2.0
# Flores             3.857143e+05  7.0
# Floresta           3.025000e+05  2.0
# Villa Pueyrredón   2.713333e+05  3.0
# Barracas           2.400000e+05  2.0
# Monte Castro       2.185000e+05  2.0
# Monserrat          2.100000e+05  2.0
# Parque Patricios   1.700000e+05  2.0
# Mataderos          1.662500e+05  4.0
# Villa Lugano       1.560000e+05  3.0
# Boca               1.514286e+05  7.0
# Retiro             1.000000e+05  2.0

# %%
#Parte Grafica del Analisis de Propiedades

# %matplotlib inline
topBarrios_hist = topBarrios['price_property']

imagen =topBarrios_hist.plot(kind='bar',rot=90,figsize=(12,8))
imagen.set_xlabel('Barrios')

imagen.set_ylabel('Precio Propiedad Promedio')

imagen.set_title('Top 10 Precio Propiedad Promedio Por Barrio')

imagenEx = imagen.get_figure()
imagenEx.savefig('/home/matias/Escritorio/Datos/GraficoNote4.jpg')

# %% [markdown]
# # Casas 2013

# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %config IPCompleter.greedy=True

df = pd.read_csv('/home/matias/Escritorio/notebook/properati-AR-2017-08-01-properties-sell.csv')

#Filtramos solo las propiedades de Capital Federal
propCF = df[df['state_name']== 'Capital Federal']

#Filtramos solo las Casas
casasCF = propCF[propCF['property_type']== 'house']

#En el año 2013
casasCF2013 = casasCF[casasCF.created_on.str.contains('2013')]

#Tomo los datos que me interesan de la tabla, en este caso solo me interesa el precio de las propiedades
casasCF2013S= casasCF2013[['place_name','place_with_parent_names','surface_total_in_m2', 'price_usd_per_m2']]

#Saco los Nan de la tabla resultante
casasCF2013S.dropna(inplace=True)

#Agrego el precio de la propiedad como columna como el producto de la superficie y el precio por m2
casasCF2013S['price_property'] = casasCF2013S['surface_total_in_m2']*casasCF2013S['price_usd_per_m2']

#Agrupo por Barrio
porBarrio = casasCF2013S.groupby('place_name').agg([np.mean, np.size])

#Elimino Capital Federal ya que es el resultado de los datos donde on estaba especificado el barrio
porBarrio2 = porBarrio

#Filtramos barrios con poca representacion de datos > de 10 publicaciones
porBarrio3 = porBarrio2.loc[porBarrio2[('price_property','size')]>0,:]
                             
#Obtengo el Top de los barrios
topBarrios = porBarrio3.sort_values([('price_property','mean')], ascending =False)
topBarrios.head(57)
# Out:
# /home/matias/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/matias/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            surface_total_in_m2      price_usd_per_m2      price_property
#                           mean size             mean size           mean size
# place_name
# Floresta                 216.0  1.0      1666.666667  1.0       360000.0  1.0
# Villa Real               143.0  1.0      1538.461538  1.0       220000.0  1.0
# Mataderos                162.0  1.0      1327.160494  1.0       215000.0  1.0
# Paternal                 158.0  1.0      1329.113924  1.0       210000.0  1.0
# Barracas                 152.0  1.0       921.052632  1.0       140000.0  1.0
